# %% [markdown]
# <a href="https://colab.research.google.com/github/Khai-Huynh1/Data-Mining-2026-Project/blob/main/data_mining_project_spring_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Mining Project Spring 2026
# ## Khai Huynh
# ## 4/29/2026
# ## AI Impact on Jobs
#
# ## Project workflow
#
# 1. **Problem Framing & Data Acquisition**
# 2. **Exploratory Data Analysis (EDA) & Data Preparation**
# 3. **Model Development, Evaluation & Business Interpretation**
#
# ## Project Overview
# - Uses a **classification dataset**
# - Uses **Random Forest** as one of your main models
# - Uses **Google Colab**
# - Includes **visualization, preparation, modeling, and interpretation**
# - Explains results in a way a manager or stakeholder could understand

# %%
# Basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# AutoViz
# %matplotlib inline
# !pip install autoviz -q
from autoviz.AutoViz_Class import AutoViz_Class

# scikit-learn tools (Colab-friendly replacement for PyCaret)
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, classification_report, cohen_kappa_score

# Models to compare
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Evaluation
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # 1: Problem Framing & Data Acquisition
#
# - Using the given dataset, the purpose of this project is to determine the impact of AI on different jobs in different sectors.
# - The target variable is the status of the job for a given employee, whether the job was unchanged, modified, or replaced.
# - The government or other labor organizations can use this model as to help mitigate the effect of AI in disrupted sectors; assist workers most affected by AI replacing or reducing jobs in their field.
# - AI like other transformative technologies tends to be a disruptive force which will and continue to shake up labor markets. By analyzing its effects on jobs we can predict who are most at risk of losing their jobs and develop to mitigating measures in the circumstances in which it happens.
# - This dataset on AI impact on jobs was sourced from Kaggle, a data science platform that hosts datasets for data science and machine learning.
# - This dataset was chosen as it reflects both an interesting development in technology while also grounding it in the reality of such a disruptive technology as it pertains to the job market.

# %% [markdown]
# ## Data loading

# %%
# Load from a direct CSV URL
data_url = "https://raw.githubusercontent.com/Khai-Huynh1/Data-Mining-2026-Project/refs/heads/main/ai_job_impact.csv"
df = pd.read_csv(data_url)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            2000 non-null   object
#  1   Age                    2000 non-null   int64
#  2   Gender                 2000 non-null   object
#  3   Education_Level        2000 non-null   object
#  4   Industry               2000 non-null   object
#  5   Job_Role               2000 non-null   object
#  6   Years_Experience       2000 non-null   int64
#  7   AI_Adoption_Level      2000 non-null   object
#  8   Automation_Risk        2000 non-null   object
#  9   Upskilling_Required    2000 non-null   object
#  10  Salary_Before_AI       2000 non-null   int64
#  11  Salary_After_AI        2000 non-null   int64
#  12  Job_Status             2000 non-null   object
#  13  Work_Hours_Per_Week    2000 non-null   int64
#  14  Remote_Work            2000 non-null   object
#  15  Job_Satisfaction       2000 non-null   int64
#  16  Productivity_Change_%  2000 non-null   float64
# dtypes: float64(1), int64(6), object(10)
# memory usage: 265.8+ KB

# %%
df.head()
# Out:
#   Employee_ID  Age  Gender Education_Level    Industry         Job_Role       \
# 0     E0001    50   Female       Bachelor       Marketing    Content Creator
# 1     E0002    45     Male    High School   Manufacturing  Quality Inspector
# 2     E0003    51   Female         Master              IT    DevOps Engineer
# 3     E0004    48     Male            PhD       Education            Teacher
# 4     E0005    24     Male       Bachelor      Healthcare             Doctor
#
#    Years_Experience AI_Adoption_Level Automation_Risk Upskilling_Required  \
# 0         26                High             High              Yes
# 1         19                 Low              Low              Yes
# 2         28              Medium           Medium              Yes
# 3         24              Medium           Medium              Yes
# 4          0                High           Medium               No
#
#    Salary_Before_AI  Salary_After_AI Job_Status  Work_Hours_Per_Week  \
# 0       106820            95455        Replaced          45
# 1        74131            72013       Unchanged          36
# 2        35311            42290        Modified          46
# 3       114478           107820        Modified          50
# 4        33890            40945        Modified          52
#
#   Remote_Work  Job_Satisfaction  Productivity_Change_%
# 0       No             5                -10.64
# 1      Yes             6                 19.05
# 2      Yes             3                 17.05
# 3       No             9                 -2.47
# 4      Yes             6                  7.03

# %% [markdown]
# # 2: Exploratory Data Analysis (EDA) & Data Preparation
#
# ## What to include
# - basic shape and structure of the data
# - variable types
# - missing values
# - class balance of the target
# - visualizations that help explain the data
# - preparation steps you used before modeling
#
# ## Suggested questions to resolve
# - Are there missing values?
# - Are the classes balanced?
# - Which variables might be useful predictors?
# - Are any variables likely to cause problems?
# - Do I need to eliminate any variables due to correlation, redundancy, or uniqueness (ex. id)?

# %%
# Basic data inspection
print("Shape:", df.shape)
display(df.head())
display(df.info())
display(df.describe(include='all').T)
# Out:
# Shape: (2000, 17)
#   Employee_ID  Age  Gender Education_Level    Industry         Job_Role       \
# 0     E0001    50   Female       Bachelor       Marketing    Content Creator
# 1     E0002    45     Male    High School   Manufacturing  Quality Inspector
# 2     E0003    51   Female         Master              IT    DevOps Engineer
# 3     E0004    48     Male            PhD       Education            Teacher
# 4     E0005    24     Male       Bachelor      Healthcare             Doctor
#
#    Years_Experience AI_Adoption_Level Automation_Risk Upskilling_Required  \
# 0         26                High             High              Yes
# 1         19                 Low              Low              Yes
# 2         28              Medium           Medium              Yes
# 3         24              Medium           Medium              Yes
# 4          0                High           Medium               No
#
#    Salary_Before_AI  Salary_After_AI Job_Status  Work_Hours_Per_Week  \
# 0       106820            95455        Replaced          45
# 1        74131            72013       Unchanged          36
# 2        35311            42290        Modified          46
# 3       114478           107820        Modified          50
# 4        33890            40945        Modified          52
#
#   Remote_Work  Job_Satisfaction  Productivity_Change_%
# 0       No             5                -10.64
# 1      Yes             6                 19.05
# 2      Yes             3                 17.05
# 3       No             9                 -2.47
# 4      Yes             6                  7.03
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            2000 non-null   object
#  1   Age                    2000 non-null   int64
#  2   Gender                 2000 non-null   object
#  3   Education_Level        2000 non-null   object
#  4   Industry               2000 non-null   object
#  5   Job_Role               2000 non-null   object
#  6   Years_Experience       2000 non-null   int64
#  7   AI_Adoption_Level      2000 non-null   object
#  8   Automation_Risk        2000 non-null   object
#  9   Upskilling_Required    2000 non-null   object
#  10  Salary_Before_AI       2000 non-null   int64
#  11  Salary_After_AI        2000 non-null   int64
#  12  Job_Status             2000 non-null   object
#  13  Work_Hours_Per_Week    2000 non-null   int64
#  14  Remote_Work            2000 non-null   object
#  15  Job_Satisfaction       2000 non-null   int64
#  16  Productivity_Change_%  2000 non-null   float64
# dtypes: float64(1), int64(6), object(10)
# memory usage: 265.8+ KB
# None
#                        count  unique      top       freq     mean     \
# Employee_ID              2000  2000          E1984     1         NaN
# Age                    2000.0   NaN            NaN   NaN      40.558
# Gender                   2000     3           Male   709         NaN
# Education_Level          2000     4       Bachelor   529         NaN
# Industry                 2000     7        Finance   300         NaN
# Job_Role                 2000    21   Data Analyst   112         NaN
# Years_Experience       2000.0   NaN            NaN   NaN     16.6635
# AI_Adoption_Level        2000     3           High   705         NaN
# Automation_Risk          2000     3           High   682         NaN
# Upskilling_Required      2000     2            Yes  1026         NaN
# Salary_Before_AI       2000.0   NaN            NaN   NaN  73942.0725
# Salary_After_AI        2000.0   NaN            NaN   NaN  78428.6425
# Job_Status               2000     3      Unchanged  1093         NaN
# Work_Hours_Per_Week    2000.0   NaN            NaN   NaN      44.851
# Remote_Work              2000     2             No  1027         NaN
# Job_Satisfaction       2000.0   NaN            NaN   NaN      6.0205
# Productivity_Change_%  2000.0   NaN            NaN   NaN     9.78582
#
#                            std        min       25%      50%       75%      \
# Employee_ID                     NaN      NaN       NaN      NaN        NaN
# Age                       10.786418     22.0      32.0     40.0       50.0
# Gender                          NaN      NaN       NaN      NaN        NaN
# Education_Level                 NaN      NaN       NaN      NaN        NaN
# Industry                        NaN      NaN       NaN      NaN        NaN
# Job_Role                        NaN      NaN       NaN      NaN        NaN
# Years_Experience          10.746675      0.0       8.0     16.0       26.0
# AI_Adoption_Level               NaN      NaN       NaN      NaN        NaN
# Automation_Risk                 NaN      NaN       NaN      NaN        NaN
# Upskilling_Required             NaN      NaN       NaN      NaN        NaN
# Salary_Before_AI       26055.823793  30036.0   51665.5  74620.0   95418.25
# Salary_After_AI        29351.599013  24447.0  54086.75  76820.5  100730.25
# Job_Status                      NaN      NaN       NaN      NaN        NaN
# Work_Hours_Per_Week         5.71254     35.0      40.0     45.0       50.0
# Remote_Work                     NaN      NaN       NaN      NaN        NaN
# Job_Satisfaction           2.006263      3.0       4.0      6.0        8.0
# Productivity_Change_%     17.187882   -19.99    -5.355     9.85    24.5825
#
#                          max
# Employee_ID                 NaN
# Age                        59.0
# Gender                      NaN
# Education_Level             NaN
# Industry                    NaN
# Job_Role                    NaN
# Years_Experience           37.0
# AI_Adoption_Level           NaN
# Automation_Risk             NaN
# Upskilling_Required         NaN
# Salary_Before_AI       119976.0
# Salary_After_AI        161745.0
# Job_Status                  NaN
# Work_Hours_Per_Week        54.0
# Remote_Work                 NaN
# Job_Satisfaction            9.0
# Productivity_Change_%     39.99

# %%
# Missing values summary
missing_summary = df.isnull().sum().sort_values(ascending=False)
missing_summary = missing_summary[missing_summary > 0]
display(missing_summary)
# Out:
# Series([], dtype: int64)

# %%
# Target Feature Examination
target = "Job_Status"

# Class balance
display(df[target].value_counts(dropna=False))
display(df[target].value_counts(normalize=True, dropna=False))
# Out:
# Job_Status
# Unchanged    1093
# Modified      801
# Replaced      106
# Name: count, dtype: int64
# Job_Status
# Unchanged    0.5465
# Modified     0.4005
# Replaced     0.0530
# Name: proportion, dtype: float64

# %% [markdown]
# ## AutoViz integration
#
# AutoViz is useful for fast exploratory analysis. It can generate many plots at once.
#
# **Important for Colab:** after AutoViz runs, use `plt.close('all')` before creating your own plots later in the notebook. This helps prevent old figures from appearing unexpectedly.

# %%
# Install and run AutoViz in Colab if needed
# You may comment this out if AutoViz is already installed in your runtime

# !pip install autoviz

from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
# AutoViz example

dfte = AV.AutoViz(
     "",
     sep=",",
     depVar=target,
     dfte=df,
     header=0,
     verbose=1,
     lowess=False,
     chart_format="svg",
     max_rows_analyzed=150000,
     max_cols_analyzed=30
 )

# Clear any queued figures after AutoViz so later plots behave normally in Colab
import matplotlib.pyplot as plt
plt.close('all')
# Out:
# Shape of your Data Set loaded: (2000, 17)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  6
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     16 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Employee_ID']
#
# ################ Multi_Classification problem #####################
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_ffc32_row0_col0, #T_ffc32_row0_col2, #T_ffc32_row0_col3, #T_ffc32_row0_col4, #T_ffc32_row0_col5, #T_ffc32_row1_col0, #T_ffc32_row1_col2, #T_ffc32_row1_col3, #T_ffc32_row1_col4, #T_ffc32_row1_col5, #T_ffc32_row2_col0, #T_ffc32_row2_col2, #T_ffc32_row2_col3, #T_ffc32_row2_col4, #T_ffc32_row2_col5, #T_ffc32_row3_col0, #T_ffc32_row3_col2, #T_ffc32_row3_col3, #T_ffc32_row3_col4, #T_ffc32_row3_col5, #T_ffc32_row4_col0, #T_ffc32_row4_col2, #T_ffc32_row4_col3, #T_ffc32_row4_col4, #T_ffc32_row4_col5, #T_ffc32_row5_col0, #T_ffc32_row5_col2, #T_ffc32_row5_col3, #T_ffc32_row5_col4, #T_ffc32_row5_col5, #T_ffc32_row6_col0, #T_ffc32_row6_col2, #T_ffc32_row6_col3, #T_ffc32_row6_col4, #T_ffc32_row6_col5, #T_ffc32_row7_col0, #T_ffc32_row7_col2, #T_ffc32_row7_col3, #T_ffc32_row7_col4, #T_ffc32_row7_col5, #T_ffc32_row8_col0, #T_ffc32_row8_col2, #T_ffc32_row8_col3, #T_ffc32_row8_col4, #T_ffc32_row8_col5, #T_ffc32_row9_col0, #T_ffc32_row9_col2, #T_ffc32_row9_col3, #T_ffc32_row9_col4, #T_ffc32_row9_col5, #T_ffc32_row10_col0, #T_ffc32_row10_col2, #T_ffc32_row10_col3, #T_ffc32_row10_col4, #T_ffc32_row10_col5, #T_ffc32_row11_col0, #T_ffc32_row11_col2, #T_ffc32_row11_col3, #T_ffc32_row11_col4, #T_ffc32_row11_col5, #T_ffc32_row12_col0, #T_ffc32_row12_col2, #T_ffc32_row12_col3, #T_ffc32_row12_col4, #T_ffc32_row12_col5, #T_ffc32_row13_col0, #T_ffc32_row13_col2, #T_ffc32_row13_col3, #T_ffc32_row13_col4, #T_ffc32_row13_col5, #T_ffc32_row14_col0, #T_ffc32_row14_col2, #T_ffc32_row14_col3, #T_ffc32_row14_col4, #T_ffc32_row14_col5, #T_ffc32_row15_col0, #T_ffc32_row15_col2, #T_ffc32_row15_col3, #T_ffc32_row15_col4, #T_ffc32_row15_col5 {
#   font-family: Segoe UI;
# }
# #T_ffc32_row0_col1, #T_ffc32_row1_col1, #T_ffc32_row2_col1, #T_ffc32_row3_col1, #T_ffc32_row4_col1, #T_ffc32_row5_col1, #T_ffc32_row6_col1, #T_ffc32_row7_col1, #T_ffc32_row8_col1, #T_ffc32_row9_col1, #T_ffc32_row10_col1, #T_ffc32_row11_col1, #T_ffc32_row12_col1, #T_ffc32_row13_col1, #T_ffc32_row14_col1, #T_ffc32_row15_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_ffc32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffc32_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_ffc32_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_ffc32_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_ffc32_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_ffc32_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_ffc32_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffc32_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_ffc32_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_ffc32_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_ffc32_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ffc32_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_ffc32_row0_col4" class="data row0 col4" >59.000000</td>
#       <td id="T_ffc32_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row1" class="row_heading level0 row1" >Gender</th>
#       <td id="T_ffc32_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_ffc32_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_ffc32_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_ffc32_row1_col3" class="data row1 col3" ></td>
#       <td id="T_ffc32_row1_col4" class="data row1 col4" ></td>
#       <td id="T_ffc32_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row2" class="row_heading level0 row2" >Education_Level</th>
#       <td id="T_ffc32_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_ffc32_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_ffc32_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_ffc32_row2_col3" class="data row2 col3" ></td>
#       <td id="T_ffc32_row2_col4" class="data row2 col4" ></td>
#       <td id="T_ffc32_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row3" class="row_heading level0 row3" >Industry</th>
#       <td id="T_ffc32_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_ffc32_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_ffc32_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ffc32_row3_col3" class="data row3 col3" ></td>
#       <td id="T_ffc32_row3_col4" class="data row3 col4" ></td>
#       <td id="T_ffc32_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row4" class="row_heading level0 row4" >Job_Role</th>
#       <td id="T_ffc32_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_ffc32_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_ffc32_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_ffc32_row4_col3" class="data row4 col3" ></td>
#       <td id="T_ffc32_row4_col4" class="data row4 col4" ></td>
#       <td id="T_ffc32_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row5" class="row_heading level0 row5" >Years_Experience</th>
#       <td id="T_ffc32_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_ffc32_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_ffc32_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_ffc32_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_ffc32_row5_col4" class="data row5 col4" >37.000000</td>
#       <td id="T_ffc32_row5_col5" class="data row5 col5" >Column has a high correlation with ['Age']. Consider dropping one of them.</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row6" class="row_heading level0 row6" >AI_Adoption_Level</th>
#       <td id="T_ffc32_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_ffc32_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_ffc32_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_ffc32_row6_col3" class="data row6 col3" ></td>
#       <td id="T_ffc32_row6_col4" class="data row6 col4" ></td>
#       <td id="T_ffc32_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row7" class="row_heading level0 row7" >Automation_Risk</th>
#       <td id="T_ffc32_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_ffc32_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_ffc32_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_ffc32_row7_col3" class="data row7 col3" ></td>
#       <td id="T_ffc32_row7_col4" class="data row7 col4" ></td>
#       <td id="T_ffc32_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row8" class="row_heading level0 row8" >Upskilling_Required</th>
#       <td id="T_ffc32_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_ffc32_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_ffc32_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_ffc32_row8_col3" class="data row8 col3" ></td>
#       <td id="T_ffc32_row8_col4" class="data row8 col4" ></td>
#       <td id="T_ffc32_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row9" class="row_heading level0 row9" >Salary_Before_AI</th>
#       <td id="T_ffc32_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_ffc32_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_ffc32_row9_col2" class="data row9 col2" >98</td>
#       <td id="T_ffc32_row9_col3" class="data row9 col3" >30036.000000</td>
#       <td id="T_ffc32_row9_col4" class="data row9 col4" >119976.000000</td>
#       <td id="T_ffc32_row9_col5" class="data row9 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ffc32_level0_row10" class="row_heading level0 r
# All Plots done
# Time to run AutoViz = 15 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
# Code for custom visualiations (optional)

# Example 1: target distribution
plt.figure(figsize=(6,4))
sns.countplot(data=df, x=target)
plt.title("Target Distribution")
plt.xticks(rotation=45)
plt.show()

# Example 2: numeric histogram for one variable
# Replace 'REPLACE_NUMERIC_COLUMN' with a numeric column from your dataset
# plt.figure(figsize=(6,4))
# sns.histplot(data=df, x='REPLACE_NUMERIC_COLUMN', kde=True)
# plt.title("Distribution of REPLACE_NUMERIC_COLUMN")
# plt.show()

# Example 3: relationship to target
# Replace with columns from your dataset
# plt.figure(figsize=(7,4))
# sns.boxplot(data=df, x=target, y='REPLACE_NUMERIC_COLUMN')
# plt.title("REPLACE_NUMERIC_COLUMN by Target")
# plt.show()

# %% [markdown]
# ## Data preparation plan
#
# Explain your preparation steps in plain language:
# - columns dropped
# - missing value handling
# - encoding categorical variables
# - train/test split strategy
# - any feature engineering
#
# Write a short summary in the markdown cell below this one.

# %% [markdown]
# ### Student preparation summary
# Replace this text with your explanation of how you prepared the data.

# %% [markdown]
# # Deliverable 3: Model Development, Evaluation & Interpretation
#
# ## What to include
# - preprocessing pipeline
# - Random Forest model
# - parameter tuning
# - evaluation on the test set
# - confusion matrix
# - kappa
# - feature importance
# - interpretation of what the results mean
#
# ## Reminder
# You should explain results in a business-friendly way, not only with technical language.

# %%
# Modeling imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    cohen_kappa_score
)

# %%
# Identify feature columns
X = df.drop(columns=[target])
y = df[target]

# If needed, convert target labels here
# Example:
# y = y.map({"No": 0, "Yes": 1})

categorical_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()
numeric_cols = X.select_dtypes(include=["number"]).columns.tolist()

print("Categorical columns:", categorical_cols)
print("Numeric columns:", numeric_cols)
# Out:
# Categorical columns: ['Employee_ID', 'Gender', 'Education_Level', 'Industry', 'Job_Role', 'AI_Adoption_Level', 'Automation_Risk', 'Upskilling_Required', 'Remote_Work']
# Numeric columns: ['Age', 'Years_Experience', 'Salary_Before_AI', 'Salary_After_AI', 'Work_Hours_Per_Week', 'Job_Satisfaction', 'Productivity_Change_%']

# %%
# Build preprocessing pipeline
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median"))
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_cols),
        ("cat", categorical_transformer, categorical_cols)
    ]
)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=123, stratify=y
)

# %%
# Baseline Random Forest model
rf_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier(random_state=123))
])

rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred))

print("Cohen's Kappa:", round(cohen_kappa_score(y_test, y_pred), 4))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#     Modified       0.88      0.99      0.93       160
#     Replaced       0.00      0.00      0.00        21
#    Unchanged       1.00      1.00      1.00       219
#
#     accuracy                           0.94       400
#    macro avg       0.63      0.66      0.64       400
# weighted avg       0.90      0.94      0.92       400
#
# Cohen's Kappa: 0.8896

# %%
# Confusion matrix
import matplotlib.pyplot as plt

plt.close('all')
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(ax=ax)
ax.set_title("Random Forest Confusion Matrix")
plt.show()

# %% [markdown]
# ## Hyperparameter tuning
#
# We do not know the best settings ahead of time, so we try multiple combinations.
#
# A parameter grid gives the model several choices for each setting. GridSearchCV tests combinations and selects the version that performs best according to the scoring metric.

# %%
# Tune the Random Forest model
param_grid = {
    "model__n_estimators": [100, 200],
    "model__max_depth": [None, 5, 10],
    "model__min_samples_split": [2, 5],
    "model__min_samples_leaf": [1, 2]
}

rf_tuning_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier(random_state=123))
])

grid_search = GridSearchCV(
    estimator=rf_tuning_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring="f1_weighted",
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
best_rf = grid_search.best_estimator_

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'model__max_depth': None, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}

# %%
# Final evaluation on the test set
best_preds = best_rf.predict(X_test)

print("Tuned Random Forest Classification Report:")
print(classification_report(y_test, best_preds))

kappa = cohen_kappa_score(y_test, best_preds)
print("Cohen's Kappa:", round(kappa, 4))
# Out:
# Tuned Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#     Modified       0.88      0.98      0.93       160
#     Replaced       0.00      0.00      0.00        21
#    Unchanged       1.00      1.00      1.00       219
#
#     accuracy                           0.94       400
#    macro avg       0.63      0.66      0.64       400
# weighted avg       0.90      0.94      0.92       400
#
# Cohen's Kappa: 0.885

# %%
# Tuned confusion matrix
plt.close('all')
cm = confusion_matrix(y_test, best_preds)

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(ax=ax)
ax.set_title("Tuned Random Forest Confusion Matrix")
plt.show()

# %% [markdown]
# ## Feature importance
#
# Feature importance helps us see which inputs influenced the Random Forest most.
#
# Be careful:
# - importance does **not** prove causation
# - importance can be split across multiple one-hot encoded columns
# - importance tells us what mattered to the model, not necessarily what matters in the real world

# %%
# Feature importance from the tuned model
import pandas as pd

feature_names = best_rf.named_steps["preprocessor"].get_feature_names_out()
importances = best_rf.named_steps["model"].feature_importances_

feature_importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values("importance", ascending=False)

display(feature_importance_df.head(15))
# Out:
#                 feature              importance
# 1647    cat__Automation_Risk_Medium   0.260257
# 1646       cat__Automation_Risk_Low   0.151018
# 1645      cat__Automation_Risk_High   0.067290
# 1642    cat__AI_Adoption_Level_High   0.053357
# 2             num__Salary_Before_AI   0.026634
# 3              num__Salary_After_AI   0.026598
# 6        num__Productivity_Change_%   0.025639
# 1             num__Years_Experience   0.022255
# 0                          num__Age   0.022118
# 1644  cat__AI_Adoption_Level_Medium   0.021529
# 4          num__Work_Hours_Per_Week   0.021159
# 5             num__Job_Satisfaction   0.016191
# 1643     cat__AI_Adoption_Level_Low   0.011665
# 1607             cat__Gender_Female   0.005882
# 1651           cat__Remote_Work_Yes   0.005817

# %%
# Plot top feature importances
top_n = 15
top_features = feature_importance_df.head(top_n).sort_values("importance")

plt.figure(figsize=(8, 6))
plt.barh(top_features["feature"], top_features["importance"])
plt.title(f"Top {top_n} Feature Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# ## Interpretation prompts
#
# Write short answers below:
# - How well did the model perform?
# - Which class was easier or harder to predict?
# - Which variables seemed most important?
# - Where did the model make mistakes?
# - How could this model be used by a real organization?
# - What would you improve next?

# %% [markdown]
# ### Student interpretation summary
# Replace this section with your final written interpretation.

# %% [markdown]
# # Optional: Save your final processed data file and model
#
# You may save your trained model if you want to show a deployment-style step.

# %%
import joblib

# Example:
# joblib.dump(best_rf, "final_model.pkl")
# print("Model saved.")

# saving data file
from google.colab import drive
drive.mount('/content/drive')

# Save to Drive
df_clean.to_csv('/content/drive/MyDrive/cleaned_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_9895/3824134608.py in <cell line: 0>()
#       7 # saving data file
#       8 from google.colab import drive
# ----> 9 drive.mount('/content/drive')
#      10
#      11 # Save to Drive
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
